# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaimaa307/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shaimaa307/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# *   List item
#
#
# ### Unit of analysis
#
# One row represents the daily performance of one content page for one client on one reporting date.
#
# ### Time window
#
# This notebook uses data from March 2026 (month = 2026-03) from the `fact_content_daily_performance` table.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
query = f"""
SELECT *
FROM read_parquet(
'{warehouse}/fact_content_daily_performance/month=2026-03/*.parquet'
)
LIMIT 5
"""

df = con.sql(query).df()

print(df.shape)
df.head()
# Out:
# (5, 31)
#   report_date           client_hash_id           content_hash_id  \
# 0  2026-03-01  client_73cda7b4e4f265ea  content_b7e512995f79d5a6
# 1  2026-03-01  client_73cda7b4e4f265ea  content_05597932fe4da067
# 2  2026-03-01  client_73cda7b4e4f265ea  content_7a105f548d9c6916
# 3  2026-03-01  client_73cda7b4e4f265ea  content_905aa32a0230694e
# 4  2026-03-01  client_73cda7b4e4f265ea  content_a3ea9792f793ec72
#
#    client_has_gsc  client_has_ga4  gsc_data_available  ga4_data_available  \
# 0            True           False                True                <NA>
# 1            True           False                True                <NA>
# 2            True           False                True                <NA>
# 3            True           False                True                <NA>
# 4            True           False                True                <NA>
#
#    gsc_impressions  gsc_clicks  gsc_sum_position  ...  sessions_ai  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# ### Features
# - gsc_impressions
# - gsc_clicks
# - gsc_sum_position
# - sessions_total
# - sessions_ai
#
# ### Label (Proxy)
# - gsc_clicks
#
# ### Context
# - report_date
# - client_has_gsc
# - client_has_ga4
#
# ### Excluded
# - client_hash_id
# - content_hash_id
#
# The identifier columns uniquely identify records and are not used as predictive features.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
features = [
    "gsc_impressions",
    "gsc_clicks",
    "gsc_sum_position",
    "sessions_total",
    "sessions_ai"
]

print("Features:", features)
print("Label: gsc_clicks")
print("Context:", ["report_date", "client_has_gsc", "client_has_ga4"])
print("Excluded:", ["client_hash_id", "content_hash_id"])
# Out:
# Features: ['gsc_impressions', 'gsc_clicks', 'gsc_sum_position', 'sessions_total', 'sessions_ai']
# Label: gsc_clicks
# Context: ['report_date', 'client_has_gsc', 'client_has_ga4']
# Excluded: ['client_hash_id', 'content_hash_id']

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# The following queries verify the grain, row count, date range, and data availability for the selected month.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Row count
con.sql(f"""
SELECT COUNT(*) AS total_rows
FROM read_parquet(
'{warehouse}/fact_content_daily_performance/month=2026-03/*.parquet'
)
""").df()
# Out:
#    total_rows
# 0     9841378

# %%
# Date range
con.sql(f"""
SELECT
MIN(report_date) AS start_date,
MAX(report_date) AS end_date
FROM read_parquet(
'{warehouse}/fact_content_daily_performance/month=2026-03/*.parquet'
)
""").df()
# Out:
#   start_date   end_date
# 0 2026-03-01 2026-03-31

# %%
# Availability
con.sql(f"""
SELECT
COUNT(*) AS available_rows
FROM read_parquet(
'{warehouse}/fact_content_daily_performance/month=2026-03/*.parquet'
)
WHERE gsc_data_available IS TRUE
""").df()
# Out:
#    available_rows
# 0         3611061

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ### Data limitations
#
#
#
# - The dataset is observational and cannot prove causation.
# - Client identities and content URLs are anonymized.
# - Clients have different amounts of historical data.
# - Results should be interpreted as decision-support rather than causal evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Data limitations documented.")
# Out:
# Data limitations documented.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
